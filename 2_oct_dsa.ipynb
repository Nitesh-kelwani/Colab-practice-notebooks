# %% [markdown]
# Kadane’s algorithm (max subarray sum), Pandas Group by, loc & iloc, Removing a row & Columns in a dataframe, Replace outliers with a value by creating dummy values using OneHotEncoder

# %%
# Kadane’s algorithm (max subarray sum)
arr=[-2,-3,4,-1,-2,1,5,-3]
arr1=[-4,-3,-2,-1]
lengt=len(arr)
sum=0
max=0
ans_star=0
ans_end=0
for i in range(lengt):
  if sum==0:
    start=i
  sum+=arr[i]
  if sum>max:
    max=sum
    ans_star=start
    ans_end=i+1
  if sum<0:
    sum=0
print(max)
print(arr[ans_star:ans_end])
# Out:
# 7
# [4, -1, -2, 1, 5]

# %%
#  Pandas Group by
import seaborn as sns
import pandas as pd

tips=sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.groupby('sex')['tip'].sum()
# Out:
# /tmp/ipython-input-4227232215.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips.groupby('sex')['tip'].sum()
# sex
# Male      485.07
# Female    246.51
# Name: tip, dtype: float64

# %%
tips.iloc[0:2]
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
tips.shape
# Out:
# (244, 7)

# %%
#  Removing a row & Columns in a dataframe
tips.drop('day',axis=1)
# Out:
#      total_bill   tip     sex smoker    time  size
# 0         16.99  1.01  Female     No  Dinner     2
# 1         10.34  1.66    Male     No  Dinner     3
# 2         21.01  3.50    Male     No  Dinner     3
# 3         23.68  3.31    Male     No  Dinner     2
# 4         24.59  3.61  Female     No  Dinner     4
# ..          ...   ...     ...    ...     ...   ...
# 239       29.03  5.92    Male     No  Dinner     3
# 240       27.18  2.00  Female    Yes  Dinner     2
# 241       22.67  2.00    Male    Yes  Dinner     2
# 242       17.82  1.75    Male     No  Dinner     2
# 243       18.78  3.00  Female     No  Dinner     2
#
# [244 rows x 6 columns]

# %%
tips.drop(1,axis=0)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [243 rows x 7 columns]

# %%
tips.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
import pandas as pd

data = {'Color': ['Red', 'Blue', 'Green', 'Blue', 'Red'],
        'Size': ['Small', 'Large', 'Medium', 'Small', 'Large']}
df = pd.DataFrame(data)

print("Original DataFrame:")
print(df)

df_encoded = pd.get_dummies(df, prefix=['Color', 'Size'], drop_first=True)

print("\nDataFrame after get_dummies:")
print(df_encoded)
# Out:
# Original DataFrame:
#    Color    Size
# 0    Red   Small
# 1   Blue   Large
# 2  Green  Medium
# 3   Blue   Small
# 4    Red   Large
#
# DataFrame after get_dummies:
#    Color_Green  Color_Red  Size_Medium  Size_Small
# 0        False       True        False        True
# 1        False      False        False       False
# 2         True      False         True       False
# 3        False      False        False        True
# 4        False       True        False       False
