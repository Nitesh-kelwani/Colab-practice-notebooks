# %% [markdown]
# Anagram Check for two strings, joins & sub queries implementation, Implement Git Merge, understand concept of origin, head, push all the above files to your github in relevant repositories maintaining clear folder structure

# %%
# Anagram Check for two strings
one="listen"
two="netsil"
if len(one)!=len(two):
  are_anagrams=False
else:
  are_anagrams=sorted(one)==sorted(two)

print(are_anagrams)
# Out:
# True
